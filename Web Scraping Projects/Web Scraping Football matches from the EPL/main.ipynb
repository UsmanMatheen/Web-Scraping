# %%
from bs4 import BeautifulSoup
import requests
url="https://fbref.com/en/comps/9/Premier-League-Stats"
data=requests.get(url).text

soup = BeautifulSoup(data,'lxml')
standing_table=soup.select('table.stats_table')[0]
links = standing_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
team_url=[f"https://fbref.com{l}" for l in links]

team_url = team_url[0]
data = requests.get(team_url)
import pandas as pd

matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches[0].head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent   xG  xGA  Poss  Attendance          Captain  \
# 0  0.0     Ipswich Town  2.6  0.5  62.0     30014.0  Virgil van Dijk
# 1  0.0        Brentford  2.5  0.5  62.0     60017.0  Virgil van Dijk
# 2  0.0   Manchester Utd  1.8  1.4  47.0     73738.0  Virgil van Dijk
# 3  1.0  Nott'ham Forest  0.9  0.4  68.0     60344.0  Virgil van Dijk
# 4  1.0         it Milan  3.1  0.6  51.0     59826.0  Virgil van Dijk
#
#   Formation Opp Formation         Referee  Match Report Notes
# ...

# %%
soup=BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/822bd0ba/2024-2025/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2024-2025/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2024-2025/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2024-2025/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202501101" />\n<script>\n/* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */\n  window.dataLayer = window.dataLayer ||[];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'consent\',\'default\',{\n        \'ad_storage\':\'denied\',\n        \'analytics_storage\':\'denied\',\n        \'ad_user_data\':\'denied\',\n        \'ad_personalization\':\'denied\',\n        \'personalization_storage\':\'denied\',\n        \'functionality_storage\':\'granted\',\n        \'security_storage\':\'granted\',\n        \'wait_for_update\': 500\n      });\n      gtag("set", "ads_data_
# ...

# %%
shooting = pd.read_html(data.text,match="Shooting")[0]
shooting.head()
# Out:
#   For Liverpool                                                              \
#            Date   Time            Comp         Round  Day Venue Result   GF
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#                          ... Standard               Expected               \
#     GA         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh
# 0  0.0     Ipswich Town  ...     14.8  0.0  0     0      2.6  2.6    0.15
# 1  0.0        Brentford  ...     13.6  1.0  0     0      2.5  2.5    0.14
# 2  0.0   Manchester Utd  ...     13.4  0.0  0     0      1.8  1.8    0.16
# ...

# %%
shooting.columns=shooting.columns.droplevel()
shooting.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  0.0     Ipswich Town  ...  14.8  0.0   0      0  2.6   2.6     0.15  -0.6
# 1  0.0        Brentford  ...  13.6  1.0   0      0  2.5   2.5     0.14  -0.5
# 2  0.0   Manchester Utd  ...  13.4  0.0   0      0  1.8   1.8     0.16   1.2
# 3  1.0  Nott'ham Forest  ...  14.9  0.0   0      0  0.9   0.9     0.07  -0.9
# 4  1.0         it Milan  ...  15.7  1.0   0      0  3.1   3.1     0.14  -0.1
#
#    np:G-xG  Match Report
# 0     -0.6  Match Report
# ...

# %%
team_data= matches[0].merge(shooting[["Date","Sh","SoT", "Dist","FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent  ...  Opp Formation         Referee  Match Report  \
# 0  0.0     Ipswich Town  ...        4-2-3-1    Tim Robinson  Match Report
# 1  0.0        Brentford  ...          4-4-2  Stuart Attwell  Match Report
# 2  0.0   Manchester Utd  ...        4-2-3-1  Anthony Taylor  Match Report
# 3  1.0  Nott'ham Forest  ...        4-2-3-1  Michael Oliver  Match Report
# 4  1.0         it Milan  ...        4-2-3-1     Espen Eskås  Match Report
#
#    Notes  Sh SoT  Dist   FK PK PKatt
# 0    NaN  18   5  14.8  0.0  0     0
# ...

# %%
shooting.shape
# Out:
# (31, 26)

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"
all_matches = []

# Example list of years to iterate over
years = [2024, 2023, 2022]

for year in years:
    # Fetch the standings page
    data = requests.get(standings_url)
    print(f"Fetched data for {year} with status code: {data.status_code}")
    time.sleep(10)  # Add delay between requests
    
    soup = BeautifulSoup(data.text, 'html.parser')
    
    # Select the standings table
    standings_table = soup.select('table.stats_table')[0]
    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    # Get the previous season link
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        # Fetch team page
        data = requests.get(team_url)
        print(f"Fetched data for team: {team_url} with status code: {data.status_code}")
        time.sleep(10)  # Add delay between requests
        
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text, 'html.parser')
        
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        
        # Fetch shooting data page
        if not links:
            print(f"Shooting data not found for team {team_name}")
            continue
        
        data = requests.get(f"https://fbref.com{links[0]}")
        print(f"Fetched shooting data for {team_name} with status code: {data.status_code}")
        time.sleep(10)  # Add delay between requests
        
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            print(f"Merge failed for {team_name}")
            continue
        
        team_data = team_data[team_data["Comp"] == "Premier League"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)

# Combine all matches into a single DataFrame
all_matches_df = pd.concat(all_matches, ignore_index=True)
print("Data scraping completed.")
# Out:
# Fetched data for 2024 with status code: 200
# Fetched data for team: https://fbref.com/en/squads/822bd0ba/Liverpool-Stats with status code: 200
# Fetched shooting data for Liverpool with status code: 200
# Fetched data for team: https://fbref.com/en/squads/18bb7c10/Arsenal-Stats with status code: 200
# Fetched shooting data for Arsenal with status code: 200
# Fetched data for team: https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats with status code: 200
# Fetched shooting data for Nottingham Forest with status code: 200
# Fetched data for team: https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats with status code: 200
# Fetched shooting data for Chelsea with status code: 200
# Fetched data for team: https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats with status code: 200
# Fetched shooting data for Newcastle United with status code: 200
# Fetched data for team: https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats with status code: 200
# ...

# %%
all_matches_df["Season"].value_counts()
# Out:
# Season
# 2023    760
# 2022    760
# 2024    398
# Name: count, dtype: int64

# %%
all_matches_df.columns=[c.lower() for c in all_matches_df.columns]

# %%
all_matches_df
# Out:
#             date   time            comp         round  day venue result   gf  \
# 0     2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1     2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2     2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3     2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4     2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 1913  2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L    1
# 1914  2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L    3
# 1915  2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L    0
# 1916  2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L    1
# 1917  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D    4
#
# ...

# %%
all_matches_df.to_csv("matches.csv")
